# %%
#Import dependencies

import pandas as pd

# %%
#Designate URL

url = 'https://en.wikipedia.org/wiki/List_of_languages_by_time_of_extinction'

# %%
#Read tables from URL using pandas

tables = pd.read_html(url)

# %%
#Turn each table into a dataframe by index

twentyfirst_df = tables[1]
twentieth_df = tables[2]
nineteenth_df = tables[3]
eighteenth_df = tables[4]
seventeenth_df = tables[5]
sixteenth_df = tables[6]
fifteenth_df = tables[7]
fourteenth_df = tables[8]
thirteenth_df = tables[9]
eleven_twelve_df = tables[10]
tenth_df = tables[11]
ninth_df = tables[12]
seventh_df = tables[13]
sixth_df = tables[14]
fifth_df = tables[15]
fourth_df = tables[16]
third_df = tables[17]
second_df = tables[18]
first_df = tables[19]
first_BCE_df = tables[20]
second_BCE_df = tables[21]
third_BCE_df = tables[22]
fourth_BCE_df = tables[23]
fifth_BCE_df = tables[24]
sixth_BCE_df = tables[25]
seventh_BCE_df = tables[26]
second_mil_BCE_df = tables[27]

# %%
#Create new column designating the century of death for timeline charts 
#identify dates for each century

twentyfirst_df['Century of Death'] = '2001-2100'
twentieth_df['Century of Death']= '1901-2000'
nineteenth_df['Century of Death']= '1801-1900'
eighteenth_df['Century of Death'] = '1701-1800'
seventeenth_df['Century of Death'] = '1601-1700'
sixteenth_df['Century of Death'] = '1501-1600'
fifteenth_df['Century of Death'] = '1401-1500'
fourteenth_df['Century of Death'] = '1301 - 1400'
thirteenth_df['Century of Death'] = '1201-1300'
eleven_twelve_df['Century of Death'] = '1001-1200'
tenth_df['Century of Death'] = '901-1000'
ninth_df['Century of Death'] = '801-900'
seventh_df['Century of Death'] = '601-700'
sixth_df['Century of Death'] = '501-600'
fifth_df['Century of Death'] = '401-500'
fourth_df['Century of Death'] = '301-400'
third_df['Century of Death'] = '201-300'
second_df['Century of Death'] = '101-200'
first_df['Century of Death'] = '1-100'
first_BCE_df['Century of Death'] = '100-1 BCE'
second_BCE_df['Century of Death'] = '200-101 BCE'
third_BCE_df['Century of Death'] = '300-201 BCE'
fourth_BCE_df['Century of Death'] = '400-301 BCE'
fifth_BCE_df['Century of Death'] = '500-401 BCE'
sixth_BCE_df['Century of Death'] = '600-501 BCE'
seventh_BCE_df['Century of Death'] = '700-601 BCE'
second_mil_BCE_df['Century of Death'] = '2000-1001 BCE'

# %%
#Put all dataframes into a variable that we can concatinate into one large dataframe

all_frames = [twentyfirst_df, twentieth_df, nineteenth_df, eighteenth_df, seventeenth_df,
              sixteenth_df, fifteenth_df, fourteenth_df, thirteenth_df, eleven_twelve_df,
              tenth_df, ninth_df, seventh_df, sixth_df, fifth_df, fourth_df, third_df,
              second_df, first_df, first_BCE_df, second_BCE_df, third_BCE_df, fourth_BCE_df,
              fifth_BCE_df, sixth_BCE_df, seventh_BCE_df, second_mil_BCE_df]

#Concatinate all frames into one big dataframe

final_frames = pd.concat(all_frames)

# %%
#Delete the column names from the consolidated datframethat were indexed as a row of data
#update column headers

final_frames.drop([0,0],axis=0).rename(columns = {0: 'Date',
                                                 1: 'Language',
                                                 2: 'Language Family',
                                                 3: 'Region',
                                                 4: 'Notes'})
# Out:
#                         Date                              Language  \
# 1            9 December 2016                                Mandan
# 2             30 August 2016                               Wichita
# 3               29 July 2016                          Gugu Thaypan
# 4              February 2016  Nuchatlaht dialect of Nuu-chah-nulth
# 5                    by 2016                               Amurdag
# 6            4 February 2014                               Klallam
# 7                5 June 2013                              Livonian
# 8              26 March 2013                                 Yurok
# 9             2 October 2012             Cromarty dialect of Scots
# 10                  ca. 2012                             Dhungaloo
# 11              11 July 2012                         Upper Chinook
# 12             10 March 2012                            Holikachuk
# 13                      2011                        Lower Arrernte
# 14           24 October 2010                                 Pazeh
# 15            20 August 2010         Cochin Indo-Portuguese Creole
# 16           26 January 2010                                Aka-Bo
# 17             November 2009                              Aka-Kora
# 18                      2009                              Aka-Jeru
# 19                      2009                              Nyawaygi
# 20                   by 2009                           Gugu Badhun
# 21                   by 2009                              Muruwari
# 22                   by 2009                         Agavotaguerra
# 23                   by 2009                                Arikem
# 24                   by 2009                              Karipúna
# 25              by 2009 [23]                      Pataxó Hã-Ha-Hãe
# 26                   by 2009                             Aribwatsa
# 27                   by 2009                                 Lelak
# 28                   by 2009                         Papora-Hoanya
# 29                      2008                         Plains Apache
# 30          after April 2008                                  Dura
# ..                       ...                                   ...
# 1                    100 BCE                             Vestinian
# 2                ca. 150 BCE                              Faliscan
# 1        ca. 3rd century BCE                              Volscian
# 2        ca. 3rd century BCE                               Aequian
# 3        ca. 3rd century BCE                               Sidetic
# 4            3rd century BCE                                Carian
# 1                ca. 300 BCE                            Philistine
# 2                ca. 300 BCE                              Scythian
# 3            4th century BCE                    Ancient Macedonian
# 4                ca. 350 BCE                               Elamite
# 5      early 4th century BCE                           Eteocypriot
# 1                ca. 400 BCE                              Lepontic
# 2      after 5th century BCE                            Tartessian
# 3            5th century BCE                              Ammonite
# 4            5th century BCE                               Moabite
# 5      maybe 5th century BCE                            Phoenician
# 1      after 6th century BCE                               Lemnian
# 2            6th century BCE                               Edomite
# 1                ca. 600 BCE                                Luwian
# 2                ca. 600 BCE                              Egyptian
# 3            7th century BCE                              Urartian
# 4   early 1st millennium BCE                            Eteocretan
# 1          ca. 1550-1050 BCE                          Cypro-Minoan
# 2               ca. 1100 BCE                               Hittite
# 3             after 1170 BCE                              Ugaritic
# 4               ca. 1200 BCE                               Hurrian
# 5               ca. 1300 BCE                                Palaic
# 6               ca. 1500 BCE                                Hattic
# 7         2nd millennium BCE                               Eblaite
# 8   early 2nd millennium BCE                              Sumerian
#
#                       Language Family  \
# 1                              Siouan
# 2                             Caddoan
# 3                        Pama-Nyungan
# 4                            Wakashan
# 5                            Iwaidjan
# 6                            Salishan
# 7                     Uralic > Finnic
# 8                               Algic
# 9                            Germanic
# 10                       Pama-Nyungan
# 11                          Chinookan
# 12                            Na-Dene
# 13                       Pama-Nyungan
# 14                       Austronesian
# 15            Portuguese-based Creole
# 16                         Andamanese
# 17                         Andamanese
# 18                         Andamanese
# 19                       Pama-Nyungan
# 20                       Pama-Nyungan
# 21                       Pama-Nyungan
# 22                           Arawakan
# 23                             Tupian
# 24                             Tupian
# 25                       unclassified
# 26                  Malayo-Polynesian
# 27                  Malayo-Polynesian
# 28                       Austronesian
# 29               Na-Dene > Athabaskan
# 30                       Sino-Tibetan
# ..                                ...
# 1                              Italic
# 2                              Italic
# 1                              Italic
# 2                              Italic
# 3                           Anatolian
# 4                           Anatolian
# 1   unclassified, maybe Indo-European
# 2                             Iranian
# 3                       Indo-European
# 4                             isolate
# 5                isolate/unclassified
# 1                              Celtic
# 2                        unclassified
# 3                             Semitic
# 4                             Semitic
# 5                             Semitic
# 1                           Tyrsenian
# 2                             Semitic
# 1                           Anatolian
# 2                         Afroasiatic
# 3                      Hurro-Urartian
# 4                isolate/unclassified
# 1                        unclassified
# 2                           Anatolian
# 3                             Semitic
# 4                      Hurro-Urartian
# 5                           Anatolian
# 6                             isolate
# 7                             Semitic
# 8                             isolate
#
#                                        Region  \
# 1                 North Dakota, United States
# 2                     Oklahoma, United States
# 3                       Queensland, Australia
# 4                    British Columbia, Canada
# 5               Northern Territory, Australia
# 6                   Washington, United States
# 7                                      Latvia
# 8                   California, United States
# 9           Northern Scotland, United Kingdom
# 10                      Queensland, Australia
# 11                      Oregon, United States
# 12                      Alaska, United States
# 13              Northern Territory, Australia
# 14                                     Taiwan
# 15                             Southern India
# 16                     Andaman Islands, India
# 17                     Andaman Islands, India
# 18                     Andaman Islands, India
# 19                      Queensland, Australia
# 20                      Queensland, Australia
# 21  Queensland and New South Wales, Australia
# 22                                     Brazil
# 23                                     Brazil
# 24                                     Brazil
# 25                                     Brazil
# 26                           Papua New Guinea
# 27                          Sarawak, Malaysia
# 28                                     Taiwan
# 29                    Oklahoma, United States
# 30                                      Nepal
# ..                                        ...
# 1                          east-central Italy
# 2                       Tuscany/Latium, Italy
# 1                               Italy; Latium
# 2                  Latium, east-central Italy
# 3                       southwestern Anatolia
# 4                       southwestern Anatolia
# 1                          Palestine; Lebanon
# 2         Pontic-Caspian steppe, Central Asia
# 3                         northeastern Greece
# 4                Persia; southern Mesopotamia
# 5                                      Cyprus
# 1                              northern Italy
# 2                                       Spain
# 3                         northwestern Jordan
# 4                         northwestern Jordan
# 5     Lebanon; Palestine; Mediterranean coast
# 1                              Lemnos, Greece
# 2                         southwestern Jordan
# 1                    Anatolia; northern Syria
# 2                               Ancient Egypt
# 3            Armenia; Georgia; Iraq; Anatolia
# 4                               Crete, Greece
# 1                                      Cyprus
# 2                                    Anatolia
# 3                                       Syria
# 4                Anatolia; Syria; Mesopotamia
# 5                          northwest Anatolia
# 6                                    Anatolia
# 7                                       Syria
# 8                                 Mesopotamia
#
#                                                 Notes Century of Death
# 1                   with the death of Edwin Benson[1]        2001-2100
# 2                 with the death of Doris McLemore[2]        2001-2100
# 3                   with the death of Tommy George[3]        2001-2100
# 4                  with the death of Alban Michael[4]        2001-2100
# 5               with the death of Charlie Mungulda[5]        2001-2100
# 6                  with the death of Hazel Sampson[6]        2001-2100
# 7              with the death of Grizelda Kristina[7]        2001-2100
# 8                with the death of Archie Thompson[8]        2001-2100
# 9                    with the death of Bobby Hogg [9]        2001-2100
# 10                 with the death of Roy Hatfield[10]        2001-2100
# 11              with the death of Gladys Thompson[11]        2001-2100
# 12         with the death of Wilson "Tiny" Deacon[12]        2001-2100
# 13      with the death of Brownie Doolan Perrurle[13]        2001-2100
# 14                   with the death of Pan Jin-yu[14]        2001-2100
# 15              with the death of William Rozario[14]        2001-2100
# 16                      with the death of Boa Sr.[15]        2001-2100
# 17                     with the death of Ms. Boro[16]        2001-2100
# 18                                               [17]        2001-2100
# 19                with the death of Willie Seaton[18]        2001-2100
# 20                                                NaN        2001-2100
# 21                                               [19]        2001-2100
# 22                                               [20]        2001-2100
# 23                                               [21]        2001-2100
# 24                                               [22]        2001-2100
# 25                                                NaN        2001-2100
# 26                                               [24]        2001-2100
# 27                                                [4]        2001-2100
# 28                                               [25]        2001-2100
# 29              with the death of Alfred Chalepah Jr.        2001-2100
# 30               with the death of Soma Devi Dura[26]        2001-2100
# ..                                                ...              ...
# 1                                                 NaN      200-101 BCE
# 2                                                 NaN      200-101 BCE
# 1                                                 NaN      300-201 BCE
# 2                                                 NaN      300-201 BCE
# 3                                                 NaN      300-201 BCE
# 4                                                 NaN      300-201 BCE
# 1                                                 NaN      400-301 BCE
# 2                              evolved into Sarmatian      400-301 BCE
# 3                                                 NaN      400-301 BCE
# 4                                                 NaN      400-301 BCE
# 5                                                 NaN      400-301 BCE
# 1                                                 NaN      500-401 BCE
# 2                                                 NaN      500-401 BCE
# 3                                                 NaN      500-401 BCE
# 4                                                 NaN      500-401 BCE
# 5                                  evolved into Punic      500-401 BCE
# 1                                               [208]      600-501 BCE
# 2                                                 NaN      600-501 BCE
# 1                                                 NaN      700-601 BCE
# 2                     evolved into Demotic by 600 BCE      700-601 BCE
# 3                                                 NaN      700-601 BCE
# 4                                                 NaN      700-601 BCE
# 1                                                 NaN    2000-1001 BCE
# 2                                                 NaN    2000-1001 BCE
# 3                 following the destruction of Ugarit    2000-1001 BCE
# 4                                                 NaN    2000-1001 BCE
# 5                                                 NaN    2000-1001 BCE
# 6                                                 NaN    2000-1001 BCE
# 7                                                 NaN    2000-1001 BCE
# 8   used as a literary and liturgical language unt...    2000-1001 BCE
#
# [430 rows x 6 columns]
