# %%
#Dependencies

import pandas as pd
import re

# %%
#Store filepaths in variables

endangered_data = 'endangered_status_data.csv'
structure_data = 'language_structure_data.csv'
time_data = 'deaths_data.csv'

# %%
#Based on researching the endangered languages database, the CSV columns are as follows: 
#1) Location_code
#2) code_val 
#3) Primary Name 
#4) alternate_names
#5) endangerment_level 
#6) num_speakers
#7) classification
#8) dialect_varieties
#9) Notes?
#10) Public_comment
#11) locations_places
#12) Region?
#13) Coordinates

#Read in DF number 1: Endangerment of languages.

endangered_df = pd.read_csv(endangered_data,
                names=['Location Code', 'Code Value', 'Language', 'Alternate Names', 'Endangerment Level',
                       'Number of Speakers', 'Classification', 'Dialect Varieties', 'Notes', 'Public Comment', 
                       'Location Places', 'Region', 'Coordinates'])

# %%
#Drop unnecessary columns

final_endangered_df = endangered_df.drop(['Location Code', 'Code Value', 'Alternate Names', 'Classification', 'Dialect Varieties',
                   'Notes', 'Public Comment', 'Location Places'], axis = 1)

# %%
#Get every set of coordinates in a separate column for each language 
coordinates_df = endangered_df.Coordinates.str.split(";", expand=True)

# %%
#There are up to 7 different coordinate locations per language. 
#Rename coordinates columns from 0-6 to "Coord 1 - Coord 7"

coords_renamed_df = coordinates_df.rename(index=str, columns=
                      {0: "coord_primary",
                      1: "coord_secondary",
                      2: "Coord 3",
                      3: "Coord 4",
                      4: "Coord 5",
                      5: "Coord 6",
                      6: "Coord 7"})

# %%
#Pull out the primary coordinates for each language and separate them into different columns

primary_coords_df = coords_renamed_df.coord_primary.str.split(",", n= -1, expand=True)
primary_coords_df = primary_coords_df.rename(columns={
                        0: "Primary Latitude",
                        1: "Primary Longitude"})


lat_col = primary_coords_df['Primary Latitude'].tolist()
lon_col = primary_coords_df['Primary Longitude'].tolist()

# %%
final_endangered_df['Latitude'] = lat_col
final_endangered_df['Longitude'] = lon_col

final_en_df = final_endangered_df

# %%
#Remove the "endangerement level" commentary by splitting the string at the parentheses

final_en_df['Endangerment Level'] = final_en_df['Endangerment Level'].str.split("(",
        n = -1, expand=True)

#Clean up the Number of Speakers column by splitting ranges and taking just the lowest number
final_en_df['Number of Speakers'] = final_en_df['Number of Speakers'].str.split("-", n=-1, expand=True)

#Delete all the weird characters and stuff out of Number of Speeakers column
final_en_df['Number of Speakers'] = final_en_df['Number of Speakers'].str.replace('\W', "")

#Drop the coordinates column that has multiple and confusing lon/lats 
final_en_df = final_en_df.drop(['Coordinates'], axis=1)
final_en_df
# Out:
#                      Language      Endangerment Level Number of Speakers  \
# 0                        !Xun             Vulnerable               14000
# 1                       'Ôrôê             Endangered                 590
# 2              (Lower) Tanana  Critically Endangered                  25
# 3                       Aasáx                Dormant                   0
# 4                       Abaga  Critically Endangered                   5
# 5                 Abai Sungai             Endangered                 500
# 6                        Abau             Threatened                7000
# 7                       Abaza             Vulnerable               47880
# 8                Abellen Ayta             Threatened                3500
# 9                     Abinomn  Critically Endangered                  50
# 10                       Abom  Critically Endangered                  15
# 11                        Abu             Threatened                2347
# 12                       Abu'             Threatened                2560
# 13                       Abui             Threatened               16000
# 14                       Abun             Threatened                3000
# 15                    Achagua             Endangered                 283
# 16                       Aché    Severely Endangered                 200
# 17                    Acheron             Vulnerable               70000
# 18                      Achi'             Vulnerable               51593
# 19                     Achuar             Threatened                5443
# 20                   Achumawi  Critically Endangered                  10
# 21               Acoma-Laguna             Threatened                4000
# 22    Adamorobe Sign Language             Threatened                  35
# 23                      Adang             Endangered                7000
# 24               Adasen Itneg             Threatened                4000
# 25                        Adi                At risk              100190
# 26            Adithinngithigh                Dormant   NoknownL1speakers
# 27              Adnyamathanha             Endangered                 100
# 28                     Adzera             Vulnerable               28900
# 29                        Aer             Endangered                 200
# ...                       ...                     ...                ...
# 3393                   Zauzou             Endangered                2100
# 3394                      Zay             Threatened                4000
# 3395           Zaysé-Zergulla             Vulnerable               17797
# 3396                    Zazao  Critically Endangered                 NaN
# 3397                     Zeem                Dormant                   0
# 3398                  Zefra'i             Threatened                3000
# 3399                Zeme Naga             Vulnerable               34100
# 3400                  Zemiaki             Endangered                 400
# 3401                   Zenaga             Endangered                 200
# 3402      Zenzontepec Chatino             Threatened                8000
# 3403                    Zhaba             Threatened                7700
# 3404                    Zialo             Vulnerable               25000
# 3405                 Zimatlán                     NaN                NaN
# 3406                 Zirenkel             Threatened                2500
# 3407                   Ziriya                Dormant                   0
# 3408              Zizilivakan             Endangered                 NaN
# 3409                     Zo'é             Endangered                 177
# 3410                     Zome             Vulnerable               17000
# 3411                     Zoró             Endangered                 599
# 3412         Zoroastrian Dari             Endangered                 NaN
# 3413                      Zul             Threatened                4000
# 3414                   Zumaya  Critically Endangered                 NaN
# 3415                     Zuni             Threatened                9000
# 3416                  Zuruahã             Endangered                 136
# 3417                     |Gui             Threatened                1470
# 3418                    ||Ani             Endangered                1000
# 3419                   ||Gana             Threatened                1030
# 3420                    ǂHoan    Severely Endangered                  40
# 3421             ǂKx'au||'ein             Threatened                 NaN
# 3422           ᏣᎳᎩ (Cherokee)             Vulnerable               16000
#
#                                   Region       Latitude       Longitude
# 0                                 Africa      -28.74358       23.983154
# 1                                Pacific       -21.4223        165.4678
# 2                          North America      65.157778         -149.37
# 3                                 Africa        -5.1948          37.738
# 4                                Pacific        -6.1883        145.5976
# 5                         Southeast Asia          5.587        118.3695
# 6                                Pacific          -3.97          141.32
# 7              Caucasus;Europe;East Asia           44.0            42.0
# 8                         Southeast Asia            NaN             NaN
# 9                         Southeast Asia          -2.92          138.89
# 10                               Pacific   -8.424996376     142.9303589
# 11                               Pacific          -4.24          144.47
# 12                               Pacific           -3.4           142.8
# 13                        Southeast Asia            NaN             NaN
# 14                        Southeast Asia          -0.52          132.19
# 15                         South America  4.41666666667          -72.25
# 16                         South America         -25.25  -55.1666666667
# 17                                Africa         10.809         30.2453
# 18    Mexico, Central America, Caribbean  15.1666666667           -90.5
# 19                         South America      -2.876318      -77.586775
# 20                         North America      41.320107     -121.129761
# 21                         North America        34.8964       -107.5816
# 22                                Africa       5.859378       -0.197951
# 23                        Southeast Asia         -8.195         124.484
# 24                        Southeast Asia            NaN             NaN
# 25                  South Asia;East Asia      28.526319       93.115814
# 26                             Australia     -12.887711      141.717248
# 27                             Australia   -30.83714135     139.1215397
# 28                               Pacific          -6.39          146.29
# 29                            South Asia      25.272921       69.290285
# ...                                  ...            ...             ...
# 3393                           East Asia        26.1554         99.2944
# 3394                              Africa         8.0728         38.8476
# 3395                              Africa  5.91666666667   37.3333333333
# 3396                             Pacific        -8.1832        159.2269
# 3397                              Africa          10.15        9.266667
# 3398                           Near East      32.805918       52.116672
# 3399                          South Asia  25.1666666667            93.5
# 3400                           Near East            NaN             NaN
# 3401                              Africa  17.3333333333           -16.0
# 3402  Mexico, Central America, Caribbean          16.53           -97.5
# 3403                           East Asia           31.4        100.4734
# 3404                              Africa            NaN             NaN
# 3405  Mexico, Central America, Caribbean            NaN             NaN
# 3406                              Africa         12.136         18.4735
# 3407                              Africa      10.350721        8.850492
# 3408                              Africa      10.343122       13.555043
# 3409                       South America          .7909        -57.1289
# 3410           South Asia;Southeast Asia          24.06           93.93
# 3411                       South America            NaN             NaN
# 3412                           Near East        31.8402         54.1625
# 3413                              Africa           10.2        9.566667
# 3414                              Africa        10.5323         14.3591
# 3415                       North America         35.082         -108.76
# 3416                       South America        -6.8828        -66.9726
# 3417                              Africa     -22.121346       22.416744
# 3418                              Africa     -18.340187       21.792755
# 3419                              Africa     -22.121346       22.416744
# 3420                              Africa     -23.735069       23.631592
# 3421                              Africa     -21.238182        21.64135
# 3422                       North America         35.113        -84.0588
#
# [3423 rows x 6 columns]

# %%
#THINGS TO DO:

#Import structure and time csv files

#Clean structure data if necessary 

#Join structure and time data to the final_en_df on 'Language'

#Export all data into a giant CSV file

#JSONify all data into a giant JSON file
